# %%
import os
import re
import yaml
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %matplotlib inline
# %config InlineBackend.figure_format='retina'

# %%
"""
Helper functions
"""
def parse_random_search_experiment(experiment_dir):
    """
    Parse experiment directory into dataframe
    """
    emd_files = []
    hparam_files = []
    lutcost_files = []
    for d in os.listdir(experiment_dir):
        single_run_dir = os.path.join(experiment_dir, d)
        emd_file_found = False
        if os.path.isdir(single_run_dir):
            # Find emd file
            for f in os.listdir(single_run_dir):
                if "emd" in f:
                    emd_file_found = True
                    emd_files.append(os.path.join(experiment_dir, d, f))
            if emd_file_found:
                for f in os.listdir(single_run_dir):
                    if "hparams.yml" in f:
                        hparam_files.append(os.path.join(experiment_dir, d, f))
                    if "lutcost" in f:
                        lutcost_files.append(os.path.join(experiment_dir, d, f))

    assert len(emd_files) == len(hparam_files), f"num emd files = {len(emd_files)}, num hparam files = {len(hparam_files)}"
    assert len(emd_files) == len(lutcost_files), f"num emd files = {len(emd_files)}, num lutcost files = {len(lutcost_files)}"

    lr = 0
    wd = 0
    lr_t0 = 0
    results_file = os.path.join(experiment_dir, "results.csv")
    with open(results_file, "w") as f:
        f.write("trial,emd,lut_cost,loss,hidden_layers,act_bits,neuron_fanin,input_bits,input_fanin,output_bits,lr,lr_t0,wd\n")
    for emd_f, hp_f, lut_f in zip(emd_files, hparam_files, lutcost_files):
        # Get EMD
        with open(emd_f, "r") as f:
            emd = float(f.read())
        trial = emd_f.split("/")[-2]
        # Get loss
        txt_file = emd_f.split("/")[-1]
        loss = float(re.findall(f'\d+\.\d+', txt_file)[0])
        # Get total lut cost
        with open(lut_f, "r") as f:
            lut_str = f.readlines()[-1]
            lut_cost = float(re.findall(f"\d+", lut_str)[0])
        # Parse hparam yml
        with open(hp_f, "r") as f:
            hps = yaml.safe_load(f)
        hidden_layers = str(hps["hidden_layer"]).replace(",", ";")
        act_bits = str(hps["activation_bitwidth"]).replace(",", ";")
        neuron_fanin = str(hps["neuron_fanin"]).replace(",", ";")
        input_bits = hps["input_bitwidth"]
        input_fanin = hps["input_fanin"]
        output_bits = hps["output_bitwidth"]
        lr = hps["lr"]
        lr_t0 = hps["warm_restart_freq"]
        wd = hps["wd"]
        with open(results_file, "a") as f:
            f.write(f"{trial}, {emd:.3f}, {lut_cost}, {loss:.3f}, {hidden_layers}, {act_bits}, {neuron_fanin}, {input_bits}, {input_fanin}, {output_bits}, {lr:.5f}, {lr_t0}, {wd:5f}\n")
    df = pd.read_csv(results_file)
    df = df.sort_values("emd", ignore_index=True)
    df.to_csv(results_file, index=False)
    return df

def parse_grid_search_experiment(experiment_dir):
    """
    Parse grid search experiment directory into dataframe
    """
    emd_files = []
    hparam_files = []
    for d in os.listdir(experiment_dir):
        single_run_dir = os.path.join(experiment_dir, d)
        emd_file_found = False
        if os.path.isdir(single_run_dir):
            # Find emd file
            for f in os.listdir(single_run_dir):
                if "emd" in f:
                    emd_file_found = True
                    emd_files.append(os.path.join(experiment_dir, d, f))
            if emd_file_found:
                for f in os.listdir(single_run_dir):
                    if "hparams.yml" in f:
                        hparam_files.append(os.path.join(experiment_dir, d, f))

    assert len(emd_files) == len(hparam_files), f"num emd files = {len(emd_files)}, num hparam files = {len(hparam_files)}"

    lr = 0
    wd = 0
    lr_t0 = 0
    batch_size = 0
    results_file = os.path.join(experiment_dir, "results.csv")
    with open(results_file, "w") as f:
        f.write("trial,emd,loss,hidden_layers,act_bits,neuron_fanin,input_bits,input_fanin,output_bits,lr,lr_t0,wd,batch_size\n")
    for emd_f, hp_f in zip(emd_files, hparam_files):
        # Example emd file
        # large_lr0.01_warm_restart_freq25_wd0.1_batch_size512/checkpoint_epoch24_loss=0.016.pth
        # Get EMD
        with open(emd_f, "r") as f:
            emd = float(f.read())
        trial = emd_f.split("/")[-2]
        # Get loss
        txt_file = emd_f.split("/")[-1]
        loss = float(re.findall(f'\d+\.\d+', txt_file)[-1])
        # Parse hparam yml
        with open(hp_f, "r") as f:
            hps = yaml.safe_load(f)
        hidden_layers = str(hps["hidden_layer"]).replace(",", ";")
        act_bits = str(hps["activation_bitwidth"]).replace(",", ";")
        neuron_fanin = str(hps["neuron_fanin"]).replace(",", ";")
        input_bits = hps["input_bitwidth"]
        input_fanin = hps["input_fanin"]
        output_bits = hps["output_bitwidth"]
        lr = hps["lr"]
        lr_t0 = hps["warm_restart_freq"]
        wd = hps["wd"]
        batch_size = hps["batch_size"]
        with open(results_file, "a") as f:
            f.write(f"{trial}, {emd:.3f}, {loss:.3f}, {hidden_layers}, {act_bits}, {neuron_fanin}, {input_bits}, {input_fanin}, {output_bits}, {lr:.5f}, {lr_t0}, {wd:5f}, {batch_size}\n")
    df = pd.read_csv(results_file)
    df = df.sort_values("emd", ignore_index=True)
    df.to_csv(results_file, index=False)
    return df

# %% [markdown]
# # LogicNets Dense-only Random Search

# %%
experiment_dir = "../hp_random_search/"

df = parse_random_search_experiment(experiment_dir)
df
# Out:
#                    trial    emd   lut_cost   loss               hidden_layers  \
# 0     hparam8_1916071045  1.419  2140224.0  0.012        [512; 256; 512; 512]
# 1     hparam17_432384445  1.434   442768.0  0.012              [512; 512; 64]
# 2     hparam17_288518158  1.463   442768.0  0.013              [512; 512; 64]
# 3    hparam17_1841208793  1.463   442768.0  0.012              [512; 512; 64]
# 4     hparam8_1317947088  1.468  2140224.0  0.012        [512; 256; 512; 512]
# ..                   ...    ...        ...    ...                         ...
# 481   hparam22_923386753  3.412   175232.0  0.157      [256; 64; 64; 256; 64]
# 482  hparam21_1664274912  3.476   497984.0  0.198    [64; 128; 512; 256; 512]
# 483  hparam22_1333950286  3.477   191072.0  0.198                [64; 64; 64]
# 484   hparam18_703051094  3.481   840432.0  0.198   [256; 256; 128; 256; 128]
# 485  hparam18_1424415738  3.498   840432.0  0.198   [256; 256; 128; 256; 128]
#
#              act_bits      neuron_fanin  input_bits  input_fanin  output_bits  \
# 0        [3; 4; 6; 3]      [5; 3; 2; 2]           5            3            4
# 1           [3; 3; 4]         [4; 5; 3]           6            2            5
# 2           [3; 3; 4]         [4; 5; 3]           6            2            5
# 3           [3; 3; 4]         [4; 5; 3]           6            2            5
# 4        [3; 4; 6; 3]      [5; 3; 2; 2]           5            3            4
# ..                ...               ...         ...          ...          ...
# 481   [2; 5; 2; 2; 2]   [3; 3; 6; 3; 4]           6            2            4
# 482   [2; 3; 4; 2; 4]   [5; 4; 3; 4; 4]           4            4            4
# 483         [2; 5; 3]         [6; 3; 5]           6            2            2
# 484   [2; 4; 4; 2; 4]   [6; 3; 4; 2; 2]           5            2            3
# 485   [2; 4; 4; 2; 4]   [6; 3; 4; 2; 2]           5            2            3
#
#           lr  lr_t0        wd
# 0    0.00530     54  0.000566
# 1    0.00211     74  0.013042
# 2    0.00211     74  0.013042
# 3    0.00211     74  0.013042
# 4    0.00530     54  0.000566
# ..       ...    ...       ...
# 481  0.00982     72  0.023980
# 482  0.00719     60  0.060653
# 483  0.00640     88  0.070434
# 484  0.00827     72  0.087084
# 485  0.00827     72  0.087084
#
# [486 rows x 13 columns]

# %%
def get_len(val):
    """
    Convert val : string to list to count length
    """
    l = eval(val.replace(";", ","))
    return len(l)

def get_max(val):
    """
    Evaluate val as list and get max value
    """
    l = eval(val.replace(";", ","))
    return max(l)

df["depth"] = df["hidden_layers"].apply(get_len)
df["max_width"] = df["hidden_layers"].apply(get_max)
df["input_bits_x_fanin"] = list(zip(df["input_bits"], df["input_fanin"]))
df
# Out:
#                    trial    emd   lut_cost   loss               hidden_layers  \
# 0     hparam8_1916071045  1.419  2140224.0  0.012        [512; 256; 512; 512]
# 1     hparam17_432384445  1.434   442768.0  0.012              [512; 512; 64]
# 2     hparam17_288518158  1.463   442768.0  0.013              [512; 512; 64]
# 3    hparam17_1841208793  1.463   442768.0  0.012              [512; 512; 64]
# 4     hparam8_1317947088  1.468  2140224.0  0.012        [512; 256; 512; 512]
# ..                   ...    ...        ...    ...                         ...
# 481   hparam22_923386753  3.412   175232.0  0.157      [256; 64; 64; 256; 64]
# 482  hparam21_1664274912  3.476   497984.0  0.198    [64; 128; 512; 256; 512]
# 483  hparam22_1333950286  3.477   191072.0  0.198                [64; 64; 64]
# 484   hparam18_703051094  3.481   840432.0  0.198   [256; 256; 128; 256; 128]
# 485  hparam18_1424415738  3.498   840432.0  0.198   [256; 256; 128; 256; 128]
#
#              act_bits      neuron_fanin  input_bits  input_fanin  output_bits  \
# 0        [3; 4; 6; 3]      [5; 3; 2; 2]           5            3            4
# 1           [3; 3; 4]         [4; 5; 3]           6            2            5
# 2           [3; 3; 4]         [4; 5; 3]           6            2            5
# 3           [3; 3; 4]         [4; 5; 3]           6            2            5
# 4        [3; 4; 6; 3]      [5; 3; 2; 2]           5            3            4
# ..                ...               ...         ...          ...          ...
# 481   [2; 5; 2; 2; 2]   [3; 3; 6; 3; 4]           6            2            4
# 482   [2; 3; 4; 2; 4]   [5; 4; 3; 4; 4]           4            4            4
# 483         [2; 5; 3]         [6; 3; 5]           6            2            2
# 484   [2; 4; 4; 2; 4]   [6; 3; 4; 2; 2]           5            2            3
# 485   [2; 4; 4; 2; 4]   [6; 3; 4; 2; 2]           5            2            3
#
#           lr  lr_t0        wd  depth  max_width input_bits_x_fanin
# 0    0.00530     54  0.000566      4        512             (5, 3)
# 1    0.00211     74  0.013042      3        512             (6, 2)
# 2    0.00211     74  0.013042      3        512             (6, 2)
# 3    0.00211     74  0.013042      3        512             (6, 2)
# 4    0.00530     54  0.000566      4        512             (5, 3)
# ..       ...    ...       ...    ...        ...                ...
# 481  0.00982     72  0.023980      5        256             (6, 2)
# 482  0.00719     60  0.060653      5        512             (4, 4)
# 483  0.00640     88  0.070434      3         64             (6, 2)
# 484  0.00827     72  0.087084      5        256             (5, 2)
# 485  0.00827     72  0.087084      5        256             (5, 2)
#
# [486 rows x 16 columns]

# %%
fig, ax = plt.subplots(figsize=(4, 3))

sns.boxplot(data=df, x="depth", y="emd", ax=ax, palette="BrBG")

fig.tight_layout()
plt.savefig("emd_v_depth_boxplot.pdf")
plt.savefig("emd_v_depth_boxplot.png")
# Out:
# /proj/xlabs/users/olivweng/opt/mambaforge/envs/jupyter/lib/python3.9/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /proj/xlabs/users/olivweng/opt/mambaforge/envs/jupyter/lib/python3.9/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /proj/xlabs/users/olivweng/opt/mambaforge/envs/jupyter/lib/python3.9/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):

# %%
"""
Bar plot to count number of trials with a neural network of certain depth
"""
fig, ax = plt.subplots(figsize=(4, 3))

ax = sns.countplot(data=df, x="depth", ax=ax, palette="BrBG", edgecolor="k")

fig.tight_layout()
plt.savefig("nn_depth_count.pdf")
plt.savefig("nn_depth_count.png")
# Out:
# /proj/xlabs/users/olivweng/opt/mambaforge/envs/jupyter/lib/python3.9/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /proj/xlabs/users/olivweng/opt/mambaforge/envs/jupyter/lib/python3.9/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /proj/xlabs/users/olivweng/opt/mambaforge/envs/jupyter/lib/python3.9/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):

# %%
fig, ax = plt.subplots(figsize=(4, 3))

sns.boxplot(data=df, x="max_width", y="emd", ax=ax, palette="GnBu")

fig.tight_layout()
plt.savefig("emd_v_max_width_boxplot.pdf")
plt.savefig("emd_v_max_width_boxplot.png")
# Out:
# /proj/xlabs/users/olivweng/opt/mambaforge/envs/jupyter/lib/python3.9/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /proj/xlabs/users/olivweng/opt/mambaforge/envs/jupyter/lib/python3.9/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /proj/xlabs/users/olivweng/opt/mambaforge/envs/jupyter/lib/python3.9/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):

# %%
"""
Bar plot to count number of trials with a neural network of max width
"""
fig, ax = plt.subplots(figsize=(4, 3))

ax = sns.countplot(data=df, x="max_width", ax=ax, palette="GnBu", edgecolor="k")

fig.tight_layout()
plt.savefig("nn_max_width_count.pdf")
plt.savefig("nn_max_width_count.png")
# Out:
# /proj/xlabs/users/olivweng/opt/mambaforge/envs/jupyter/lib/python3.9/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /proj/xlabs/users/olivweng/opt/mambaforge/envs/jupyter/lib/python3.9/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /proj/xlabs/users/olivweng/opt/mambaforge/envs/jupyter/lib/python3.9/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):

# %%
"""
Scatter plot EMD vs learning rate
"""
fig, ax = plt.subplots(figsize=(4, 3))
ax = sns.scatterplot(data=df, x="lr", y="emd", ax=ax, palette="pastel")

ax.set_xscale("log")
ax.grid()

fig.tight_layout()
plt.savefig("emd_v_lr_scatterplot.pdf")
plt.savefig("emd_v_lr_scatterplot.png")
# Out:
# /proj/xlabs/users/olivweng/opt/mambaforge/envs/jupyter/lib/python3.9/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /proj/xlabs/users/olivweng/opt/mambaforge/envs/jupyter/lib/python3.9/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /tmp/ipykernel_1785453/2680488147.py:5: UserWarning: Ignoring `palette` because no `hue` variable has been assigned.
#   ax = sns.scatterplot(data=df, x="lr", y="emd", ax=ax, palette="pastel")

# %%
"""
Scatter plot EMD vs warm restart frequency
"""
fig, ax = plt.subplots(figsize=(4, 3))
ax = sns.scatterplot(data=df, x="lr_t0", y="emd", ax=ax, palette="pastel")

ax.grid()
ax.set_xlabel("Warm restart frequency (Epochs)")

fig.tight_layout()
plt.savefig("emd_v_lr_t0_scatterplot.pdf")
plt.savefig("emd_v_lr_t0_scatterplot.png")
# Out:
# /proj/xlabs/users/olivweng/opt/mambaforge/envs/jupyter/lib/python3.9/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /proj/xlabs/users/olivweng/opt/mambaforge/envs/jupyter/lib/python3.9/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /tmp/ipykernel_1785453/2298605004.py:5: UserWarning: Ignoring `palette` because no `hue` variable has been assigned.
#   ax = sns.scatterplot(data=df, x="lr_t0", y="emd", ax=ax, palette="pastel")

# %%
"""
Scatter plot EMD vs weight decay
"""
fig, ax = plt.subplots(figsize=(4, 3))
ax = sns.scatterplot(data=df, x="wd", y="emd", ax=ax, palette="pastel")

ax.set_xscale("log")
ax.grid()

fig.tight_layout()
plt.savefig("emd_v_wd_scatterplot.pdf")
plt.savefig("emd_v_wd_scatterplot.png")
# Out:
# /proj/xlabs/users/olivweng/opt/mambaforge/envs/jupyter/lib/python3.9/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /proj/xlabs/users/olivweng/opt/mambaforge/envs/jupyter/lib/python3.9/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /tmp/ipykernel_1785453/2479843373.py:5: UserWarning: Ignoring `palette` because no `hue` variable has been assigned.
#   ax = sns.scatterplot(data=df, x="wd", y="emd", ax=ax, palette="pastel")

# %%
"""
Box plot EMD vs number of input_bits
"""
fig, ax = plt.subplots(figsize=(4, 3))
sns.boxplot(data=df, x="input_bits", y="emd", ax=ax, palette="BuPu")

fig.tight_layout()
plt.savefig("emd_v_input_bits_boxplot.pdf")
plt.savefig("emd_v_input_bits_boxplot.png")
# Out:
# /proj/xlabs/users/olivweng/opt/mambaforge/envs/jupyter/lib/python3.9/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /proj/xlabs/users/olivweng/opt/mambaforge/envs/jupyter/lib/python3.9/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /proj/xlabs/users/olivweng/opt/mambaforge/envs/jupyter/lib/python3.9/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):

# %%
"""
Scatter plot EMD vs input fanin
"""
fig, ax = plt.subplots(figsize=(4, 3))
sns.boxplot(data=df, x="input_fanin", y="emd", ax=ax, palette="BuPu")

fig.tight_layout()
plt.savefig("emd_v_input_fanin_boxplot.pdf")
plt.savefig("emd_v_input_fanin_boxplot.png")
# Out:
# /proj/xlabs/users/olivweng/opt/mambaforge/envs/jupyter/lib/python3.9/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /proj/xlabs/users/olivweng/opt/mambaforge/envs/jupyter/lib/python3.9/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /proj/xlabs/users/olivweng/opt/mambaforge/envs/jupyter/lib/python3.9/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):

# %%
"""
Box plot EMD vs input_bits_x_fanin
"""
fig, ax = plt.subplots(figsize=(4, 3))
sns.boxplot(data=df, x="input_bits_x_fanin", y="emd", ax=ax, palette="BuPu")

ax.set_xlabel("(input bits, input fanin)")

fig.tight_layout()
plt.savefig("emd_v_input_bits_x_fanin_boxplot.pdf")
plt.savefig("emd_v_input_bits_x_fanin_boxplot.png")
# Out:
# /proj/xlabs/users/olivweng/opt/mambaforge/envs/jupyter/lib/python3.9/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /proj/xlabs/users/olivweng/opt/mambaforge/envs/jupyter/lib/python3.9/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /proj/xlabs/users/olivweng/opt/mambaforge/envs/jupyter/lib/python3.9/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):

# %%
"""
Bar plot to count number of trials with a neural network with setting (input bits, input fanin)
"""
fig, ax = plt.subplots(figsize=(4, 3))

ax = sns.countplot(data=df, x="input_bits_x_fanin", ax=ax, palette="GnBu", edgecolor="k")

fig.tight_layout()
plt.savefig("input_bits_x_fanin_count.pdf")
plt.savefig("input_bits_x_fanin_count.png")
# Out:
# /proj/xlabs/users/olivweng/opt/mambaforge/envs/jupyter/lib/python3.9/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /proj/xlabs/users/olivweng/opt/mambaforge/envs/jupyter/lib/python3.9/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /proj/xlabs/users/olivweng/opt/mambaforge/envs/jupyter/lib/python3.9/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):

# %%
"""
Box plot EMD vs number of output_bits
"""
fig, ax = plt.subplots(figsize=(4, 3))
sns.boxplot(data=df, x="output_bits", y="emd", ax=ax, palette="BuPu")

fig.tight_layout()
plt.savefig("emd_v_output_bits_boxplot.pdf")
plt.savefig("emd_v_output_bits_boxplot.png")
# Out:
# /proj/xlabs/users/olivweng/opt/mambaforge/envs/jupyter/lib/python3.9/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /proj/xlabs/users/olivweng/opt/mambaforge/envs/jupyter/lib/python3.9/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /proj/xlabs/users/olivweng/opt/mambaforge/envs/jupyter/lib/python3.9/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):

# %%
"""
Bar plot to count number of trials with a neural network with different number of output bits
"""
fig, ax = plt.subplots(figsize=(4, 3))

ax = sns.countplot(data=df, x="output_bits", ax=ax, palette="BuPu", edgecolor="k")

fig.tight_layout()
plt.savefig("output_bits_count.pdf")
plt.savefig("output_bits_count.png")
# Out:
# /proj/xlabs/users/olivweng/opt/mambaforge/envs/jupyter/lib/python3.9/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /proj/xlabs/users/olivweng/opt/mambaforge/envs/jupyter/lib/python3.9/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /proj/xlabs/users/olivweng/opt/mambaforge/envs/jupyter/lib/python3.9/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):

# %%
# TODO: Plot emd vs first/last layer width box plot

# %%
"""
Scatter plot avg EMD (over 3 random seeds) vs LUTCost
"""

df2 = df[df.duplicated("lut_cost", keep=False)].groupby("lut_cost")["emd"].apply(list).reset_index()
df2["avg_emd"] = df2["emd"].apply(np.mean)
df2 = df2.sort_values("emd", ignore_index=True)
df2
# Out:
#       lut_cost                    emd   avg_emd
# 0    2140224.0  [1.419, 1.468, 1.511]  1.466000
# 1     442768.0  [1.434, 1.463, 1.463]  1.453333
# 2     621936.0  [1.472, 1.486, 1.587]  1.515000
# 3    2887648.0   [1.498, 1.61, 1.823]  1.643667
# 4     963728.0  [1.515, 1.655, 1.755]  1.641667
# ..         ...                    ...       ...
# 157   175232.0  [2.498, 2.976, 3.412]  2.962000
# 158   191072.0  [2.559, 2.843, 3.477]  2.959667
# 159   286064.0  [2.692, 2.767, 2.929]  2.796000
# 160  2304160.0  [2.859, 2.919, 3.104]  2.960667
# 161    87472.0  [2.961, 3.059, 3.359]  3.126333
#
# [162 rows x 3 columns]

# %%
"""
Scatter plot EMD vs LUTCost
"""
def is_pareto_efficient(costs):
    """
    From: https://stackoverflow.com/questions/32791911/fast-calculation-of-pareto-front-in-python
    Find the pareto-efficient points
    :param costs: An (n_points, n_costs) array
    :return: A (n_points, ) boolean array, indicating whether each point is Pareto efficient
    """
    is_efficient = np.ones(costs.shape[0], dtype = bool)
    for i, c in enumerate(costs):
        is_efficient[i] = np.all(np.any(costs[:i]>c, axis=1)) and np.all(np.any(costs[i+1:]>c, axis=1))
    return is_efficient

# Pareto front for individual runs
costs = np.array(list(zip(df["lut_cost"], df["emd"])))
pareto_front_bool_array = is_pareto_efficient(costs)
print(f"pareto rows: {np.arange(len(costs))[pareto_front_bool_array]}")
pareto_front = costs[pareto_front_bool_array]
print(pareto_front)
pareto_lutcost = pareto_front[:, 0]
pareto_emd = pareto_front[:, 1]

# Pareto frot for averaged runs (averaged emd across 3 random seeds) b/c each
# random search trial was run with 3 random seeds
avg_costs = np.array(list(zip(df2["lut_cost"], df2["avg_emd"])))
pareto_front_bool_array = is_pareto_efficient(avg_costs)
print(f"avg pareto rows: {np.arange(len(avg_costs))[pareto_front_bool_array]}")
avg_pareto_front = avg_costs[pareto_front_bool_array]
print(avg_pareto_front)
avg_pareto_lutcost = avg_pareto_front[:, 0]
avg_pareto_emd = avg_pareto_front[:, 1]

fig, ax = plt.subplots(figsize=(7, 5))
ax = sns.scatterplot(data=df, x="lut_cost", y="emd", ax=ax, label="Random search trials")
ax = sns.scatterplot(data=df2, x="lut_cost", y="avg_emd", ax=ax, color="orange", label="Averaged EMD random search")

ax = sns.lineplot(x=pareto_lutcost, y=pareto_emd, ax=ax, color="navy", label="Pareto front")
ax = sns.lineplot(x=avg_pareto_lutcost, y=avg_pareto_emd, ax=ax, color="red", label="Avg EMD Pareto front")
# ax = sns.scatterplot(x=[pareto_lutcost[0]], y=[pareto_emd[0]], ax=ax, marker="X", color="cyan", label="Large model")
# ax = sns.scatterplot(x=[pareto_lutcost[1]], y=[pareto_emd[1]], ax=ax, marker="X", color="magenta", label="Medium model")
# ax = sns.scatterplot(x=[pareto_lutcost[2]], y=[pareto_emd[2]], ax=ax, marker="X", color="limegreen", label="Small model")


ax.legend()
ax.grid()
ax.set_xscale("log")

fig.tight_layout()
plt.savefig("emd_v_lutcost_scatterplot.pdf")
plt.savefig("emd_v_lutcost_scatterplot.png")
# Out:
# pareto rows: [  0   1  19  21  29  49  64  73 180 355]
# [[2.140224e+06 1.419000e+00]
#  [4.427680e+05 1.434000e+00]
#  [3.901120e+05 1.550000e+00]
#  [3.760000e+05 1.554000e+00]
#  [3.327840e+05 1.573000e+00]
#  [1.660320e+05 1.604000e+00]
#  [6.217600e+04 1.628000e+00]
#  [3.931200e+04 1.646000e+00]
#  [1.510400e+04 1.774000e+00]
#  [1.078400e+04 1.994000e+00]]
# avg pareto rows: [  1  18  27  33  37  88 140]
# [[4.42768000e+05 1.45333333e+00]
#  [3.32784000e+05 1.63866667e+00]
#  [1.66032000e+05 1.64133333e+00]
#  [6.21760000e+04 1.69800000e+00]
#  [3.93120000e+04 1.78600000e+00]
#  [1.51040000e+04 1.83666667e+00]
#  [1.07840000e+04 2.03566667e+00]]
# /proj/xlabs/users/olivweng/opt/mambaforge/envs/jupyter/lib/python3.9/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /proj/xlabs/users/olivweng/opt/mambaforge/envs/jupyter/lib/python3.9/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /proj/xlabs/users/olivweng/opt/mambaforge/envs/jupyter/lib/python3.9/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /proj/xlabs/users/olivweng/opt/mambaforge/envs/jupyter/lib/python3.9/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /proj/xlabs/users/olivweng/opt/mambaforge/envs/jupyter/lib/python3.9/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /proj/xlabs/users/olivweng/opt/mambaforge/envs/jupyter/lib/python3.9/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /proj/xlabs/users/olivweng/opt/mambaforge/envs/jupyter/lib/python3.9/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /proj/xlabs/users/olivweng/opt/mambaforge/envs/jupyter/lib/python3.9/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /proj/xlabs/users/olivweng/opt/mambaforge/envs/jupyter/lib/python3.9/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /proj/xlabs/users/olivweng/opt/mambaforge/envs/jupyter/lib/python3.9/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /proj/xlabs/users/olivweng/opt/mambaforge/envs/jupyter/lib/python3.9/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /proj/xlabs/users/olivweng/opt/mambaforge/envs/jupyter/lib/python3.9/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %%
"""
Scatter plot avg EMD vs LUTCost
"""
fig, ax = plt.subplots(figsize=(7, 5))
ax = sns.scatterplot(data=df2, x="lut_cost", y="avg_emd", ax=ax, label="Averaged EMD random search")

ax = sns.lineplot(x=avg_pareto_lutcost, y=avg_pareto_emd, ax=ax, color="orange", label="Pareto front")
ax = sns.scatterplot(x=[avg_pareto_lutcost[3]], y=[avg_pareto_emd[3]], ax=ax, marker="X", color="limegreen", label="Small model")
ax = sns.scatterplot(x=[avg_pareto_lutcost[2]], y=[avg_pareto_emd[2]], ax=ax, marker="X", color="magenta", label="Medium model")
ax = sns.scatterplot(x=[avg_pareto_lutcost[0]], y=[avg_pareto_emd[0]], ax=ax, marker="X", color="cyan", label="Large model")

ax.legend()
ax.grid()
ax.set_xscale("log")

fig.tight_layout()
plt.savefig("avg_emd_v_lutcost_scatterplot.pdf")
plt.savefig("avg_emd_v_lutcost_scatterplot.png")
# Out:
# /proj/xlabs/users/olivweng/opt/mambaforge/envs/jupyter/lib/python3.9/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /proj/xlabs/users/olivweng/opt/mambaforge/envs/jupyter/lib/python3.9/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /proj/xlabs/users/olivweng/opt/mambaforge/envs/jupyter/lib/python3.9/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /proj/xlabs/users/olivweng/opt/mambaforge/envs/jupyter/lib/python3.9/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /proj/xlabs/users/olivweng/opt/mambaforge/envs/jupyter/lib/python3.9/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /proj/xlabs/users/olivweng/opt/mambaforge/envs/jupyter/lib/python3.9/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /proj/xlabs/users/olivweng/opt/mambaforge/envs/jupyter/lib/python3.9/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /proj/xlabs/users/olivweng/opt/mambaforge/envs/jupyter/lib/python3.9/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /proj/xlabs/users/olivweng/opt/mambaforge/envs/jupyter/lib/python3.9/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /proj/xlabs/users/olivweng/opt/mambaforge/envs/jupyter/lib/python3.9/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /proj/xlabs/users/olivweng/opt/mambaforge/envs/jupyter/lib/python3.9/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /proj/xlabs/users/olivweng/opt/mambaforge/envs/jupyter/lib/python3.9/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):

# %% [markdown]
# ## LogicNets Grid Search for Top 3 random search models
# * Small model: `hparam19_2036987025`
#     * hidden layers: `[256, 256]`
#     * Random search EMD: 1.55
#     * LUTCost: 390,112
# * Medium model: `hparam17_432384445`
#     * hidden layers: `[512; 512; 64]`
#     * Random search EMD: 1.434
#     * LUTCost: 442,768
# * Large model: `hparam8_1916071045`
#     * hidden layers: `[512; 256; 512; 512]`
#     * Random search EMD: 1.419
#     * LUTCost: 2,140,224

# %%
experiment_dir = "../sml_hp_grid_search/"
df = parse_grid_search_experiment(experiment_dir)
df
# Out:
#                                                  trial    emd   loss  \
# 0    large_lr0.001_warm_restart_freq50_wd0.0001_bat...  1.385  0.012
# 1    large_lr0.001_warm_restart_freq100_wd0.01_batc...  1.400  0.011
# 2    large_lr0.001_warm_restart_freq50_wd0.01_batch...  1.404  0.012
# 3    medium_lr0.001_warm_restart_freq100_wd0.01_bat...  1.407  0.012
# 4    large_lr0.001_warm_restart_freq100_wd0.01_batc...  1.414  0.012
# ..                                                 ...    ...    ...
# 103  small_lr0.01_warm_restart_freq100_wd0.1_batch_...  1.730  0.022
# 104  medium_lr0.01_warm_restart_freq50_wd0.1_batch_...  1.734  0.022
# 105  small_lr0.01_warm_restart_freq50_wd0.1_batch_s...  1.742  0.022
# 106  medium_lr0.01_warm_restart_freq100_wd0.1_batch...  1.747  0.024
# 107  medium_lr0.01_warm_restart_freq100_wd0.1_batch...  1.753  0.023
#
#              hidden_layers       act_bits   neuron_fanin  input_bits  \
# 0     [512; 256; 512; 512]   [3; 4; 6; 3]   [5; 3; 2; 2]           5
# 1     [512; 256; 512; 512]   [3; 4; 6; 3]   [5; 3; 2; 2]           5
# 2     [512; 256; 512; 512]   [3; 4; 6; 3]   [5; 3; 2; 2]           5
# 3           [512; 512; 64]      [3; 3; 4]      [4; 5; 3]           6
# 4     [512; 256; 512; 512]   [3; 4; 6; 3]   [5; 3; 2; 2]           5
# ..                     ...            ...            ...         ...
# 103             [256; 256]         [2; 6]         [5; 2]           5
# 104         [512; 512; 64]      [3; 3; 4]      [4; 5; 3]           6
# 105             [256; 256]         [2; 6]         [5; 2]           5
# 106         [512; 512; 64]      [3; 3; 4]      [4; 5; 3]           6
# 107         [512; 512; 64]      [3; 3; 4]      [4; 5; 3]           6
#
#      input_fanin  output_bits     lr  lr_t0      wd  batch_size
# 0              3            4  0.001     50  0.0001         512
# 1              3            4  0.001    100  0.0100        1024
# 2              3            4  0.001     50  0.0100        1024
# 3              2            5  0.001    100  0.0100         512
# 4              3            4  0.001    100  0.0100         512
# ..           ...          ...    ...    ...     ...         ...
# 103            3            6  0.010    100  0.1000         512
# 104            2            5  0.010     50  0.1000         512
# 105            3            6  0.010     50  0.1000         512
# 106            2            5  0.010    100  0.1000         512
# 107            2            5  0.010    100  0.1000        1024
#
# [108 rows x 13 columns]

# %% [markdown]
# ## LogicNets Grid Search for 3 Pareto models from random search
# (after averaging EMD across 3 random seeds per model)
# * Small model: `hparam11_963241121`
#     * hidden layers: `[128; 256; 128; 128]`
#     * Random search avg EMD: 1.698
#     * Random search best EMD: 1.628
#     * Grid search best EMD: 1.589
#     * LUTCost: 62,176
# * Medium model: `hparam18_524926359`
#     * hidden layers: `[128; 256; 256; 256; 256; 128]`
#     * Random search avg EMD: 1.641
#     * Random search best EMD: 1.604
#     * Grid search best EMD: 1.558
#     * LUTCost: 166,032
# * Large model: `hparam17_432384445`
#     * hidden layers: `[512; 512; 64]`
#     * Random search avg EMD: 1.453
#     * Random search best EMD: 1.434
#     * Grid search best EMD: 1.407
#     * LUTCost: 442,768

# %%
experiment_dir = "../sml_avg_emd_hp_grid_search/"
df = parse_grid_search_experiment(experiment_dir)
df
# Out:
#                                                  trial    emd   loss  \
# 0    large_lr0.001_warm_restart_freq100_wd0.01_batc...  1.407  0.012
# 1    large_lr0.001_warm_restart_freq50_wd0.01_batch...  1.420  0.012
# 2    large_lr0.001_warm_restart_freq50_wd0.001_batc...  1.422  0.012
# 3    large_lr0.001_warm_restart_freq100_wd0.01_batc...  1.425  0.012
# 4    large_lr0.001_warm_restart_freq50_wd0.001_batc...  1.451  0.013
# ..                                                 ...    ...    ...
# 115  medium_lr0.01_warm_restart_freq100_wd0.01_batc...  2.330  0.065
# 116  small_lr0.01_warm_restart_freq50_wd0.01_batch_...  2.334  0.055
# 117  small_lr0.01_warm_restart_freq100_wd0.01_batch...  2.372  0.064
# 118  medium_lr0.01_warm_restart_freq50_wd0.01_batch...  2.516  0.066
# 119  small_lr0.01_warm_restart_freq50_wd0.01_batch_...  2.752  0.067
#
#                        hidden_layers             act_bits  \
# 0                     [512; 512; 64]            [3; 3; 4]
# 1                     [512; 512; 64]            [3; 3; 4]
# 2                     [512; 512; 64]            [3; 3; 4]
# 3                     [512; 512; 64]            [3; 3; 4]
# 4                     [512; 512; 64]            [3; 3; 4]
# ..                               ...                  ...
# 115   [128; 256; 256; 256; 256; 128]   [2; 2; 3; 4; 3; 4]
# 116             [128; 256; 128; 128]         [2; 2; 2; 6]
# 117             [128; 256; 128; 128]         [2; 2; 2; 6]
# 118   [128; 256; 256; 256; 256; 128]   [2; 2; 3; 4; 3; 4]
# 119             [128; 256; 128; 128]         [2; 2; 2; 6]
#
#             neuron_fanin  input_bits  input_fanin  output_bits     lr  lr_t0  \
# 0              [4; 5; 3]           6            2            5  0.001    100
# 1              [4; 5; 3]           6            2            5  0.001     50
# 2              [4; 5; 3]           6            2            5  0.001     50
# 3              [4; 5; 3]           6            2            5  0.001    100
# 4              [4; 5; 3]           6            2            5  0.001     50
# ..                   ...         ...          ...          ...    ...    ...
# 115   [4; 6; 4; 2; 3; 2]           4            2            5  0.010    100
# 116         [6; 5; 4; 2]           4            2            6  0.010     50
# 117         [6; 5; 4; 2]           4            2            6  0.010    100
# 118   [4; 6; 4; 2; 3; 2]           4            2            5  0.010     50
# 119         [6; 5; 4; 2]           4            2            6  0.010     50
#
#         wd  batch_size
# 0    0.010         512
# 1    0.010         512
# 2    0.001         512
# 3    0.010        1024
# 4    0.001        1024
# ..     ...         ...
# 115  0.010         512
# 116  0.010         512
# 117  0.010         512
# 118  0.010         512
# 119  0.010        1024
#
# [120 rows x 13 columns]

# %% [markdown]
# ## Ensemble Learning results

# %%
def parse_ensembling_experiment(experiment_dir):
    """
    Parse ensemble learning experiment directory into dataframe
    """
    emd_files = []
    for d in os.listdir(experiment_dir):
        single_run_dir = os.path.join(experiment_dir, d)
        if "hparam" in single_run_dir:
            continue
        if os.path.isdir(single_run_dir):
            # Find emd file
            for f in os.listdir(single_run_dir):
                if "emd" in f:
                    emd_files.append(os.path.join(experiment_dir, d, f))
    results_file = os.path.join(experiment_dir, "results.csv")
    with open(results_file, "w") as f:
        f.write("trial,emd,loss,ensemble_size,model_size\n")
    for emd_f in emd_files:
        # Example emd file
        # averaging_medium_ensemble_size2_seed2_loss=0.011_emd.txt
        # Get EMD
        with open(emd_f, "r") as f:
            emd = float(f.read())
        trial = emd_f.split("/")[-2]
        # Get loss
        txt_file = emd_f.split("/")[-1]
        loss = float(re.findall(f'\d+\.\d+', txt_file)[-1])
        ensemble_size = int(re.findall(f"\d+", txt_file)[0])
        # Get model size
        if "small" in txt_file:
            model_size = "small"
        elif "medium_fr" in txt_file:
            model_size = 'medium_fr'
        elif "medium" in txt_file:
            model_size = "medium"
        elif "large" in txt_file:
            model_size = "large"
        with open(results_file, "a") as f:
            f.write(f"{trial}, {emd:.3f}, {loss:.3f}, {ensemble_size},{model_size}\n")
    df = pd.read_csv(results_file)
    df = df.sort_values("emd", ignore_index=True)
    df.to_csv(results_file, index=False)
    return df

# %% [markdown]
# ## Averaging

# %%
experiment_dir = "../averaging"
df = parse_ensembling_experiment(experiment_dir)
best_single_model_large = {
    "trial": "best_single_model_large",
    "emd": 1.407,
    "loss": 0.012,
    "ensemble_size": 1,
    "model_size": "large",
}
best_single_model_medium = {
    "trial": "best_single_model_medium",
    "emd": 1.558,
    "loss": 0.03,
    "ensemble_size": 1,
    "model_size": "medium",
}
best_single_model_small = {
    "trial": "best_single_model_small",
    "emd": 1.589,
    "loss": 0.022,
    "ensemble_size": 1,
    "model_size": "small",
}
best_single_model_large_df = pd.DataFrame(best_single_model_large, index=[0])
best_single_model_medium_df = pd.DataFrame(best_single_model_medium, index=[0])
best_single_model_small_df = pd.DataFrame(best_single_model_small, index=[0])
df = pd.concat([df, best_single_model_large_df])
df = pd.concat([df, best_single_model_medium_df])
df = pd.concat([df, best_single_model_small_df])
df = df.sort_values("emd", ignore_index=True)
averaging_df = df
df
# Out:
#                                              trial    emd   loss  \
# 0            averaging_small_ensemble_size32_seed1  1.139  0.007
# 1           averaging_medium_ensemble_size32_seed1  1.153  0.007
# 2            averaging_large_ensemble_size16_seed1  1.157  0.007
# 3             averaging_large_ensemble_size8_seed2  1.182  0.007
# 4     averaging_large_ensemble_size8_seed432384445  1.185  0.007
# 5            averaging_large_ensemble_size32_seed2  1.190  0.006
# 6   averaging_medium_ensemble_size16_seed524926359  1.196  0.007
# 7   averaging_medium_ensemble_size32_seed524926359  1.217  0.007
# 8           averaging_medium_ensemble_size16_seed1  1.218  0.008
# 9    averaging_large_ensemble_size16_seed432384445  1.228  0.009
# 10            averaging_large_ensemble_size4_seed1  1.247  0.007
# 11           averaging_medium_ensemble_size8_seed2  1.248  0.008
# 12           averaging_medium_ensemble_size8_seed1  1.260  0.009
# 13   averaging_medium_ensemble_size8_seed524926359  1.269  0.009
# 14           averaging_small_ensemble_size16_seed1  1.271  0.008
# 15           averaging_small_ensemble_size16_seed2  1.285  0.008
# 16   averaging_small_ensemble_size32_seed963241121  1.285  0.014
# 17            averaging_large_ensemble_size2_seed1  1.308  0.009
# 18          averaging_medium_ensemble_size32_seed2  1.311  0.011
# 19           averaging_medium_ensemble_size4_seed1  1.313  0.012
# 20           averaging_small_ensemble_size32_seed2  1.322  0.013
# 21           averaging_medium_ensemble_size4_seed2  1.327  0.012
# 22            averaging_small_ensemble_size8_seed1  1.329  0.010
# 23           averaging_large_ensemble_size16_seed2  1.330  0.010
# 24    averaging_large_ensemble_size2_seed432384445  1.340  0.010
# 25   averaging_small_ensemble_size16_seed963241121  1.344  0.011
# 26            averaging_small_ensemble_size8_seed2  1.353  0.011
# 27            averaging_large_ensemble_size2_seed2  1.372  0.011
# 28           averaging_large_ensemble_size32_seed1  1.374  0.010
# 29                         best_single_model_large  1.407  0.012
# 30            averaging_small_ensemble_size4_seed1  1.409  0.012
# 31    averaging_large_ensemble_size4_seed432384445  1.420  0.013
# 32            averaging_large_ensemble_size8_seed1  1.438  0.012
# 33    averaging_small_ensemble_size8_seed963241121  1.448  0.014
# 34   averaging_medium_ensemble_size4_seed524926359  1.483  0.017
# 35           averaging_medium_ensemble_size2_seed2  1.507  0.021
# 36    averaging_small_ensemble_size2_seed963241121  1.515  0.017
# 37            averaging_small_ensemble_size2_seed1  1.519  0.017
# 38                        best_single_model_medium  1.558  0.030
# 39   averaging_medium_ensemble_size2_seed524926359  1.579  0.018
# 40                         best_single_model_small  1.589  0.022
# 41    averaging_small_ensemble_size4_seed963241121  1.593  0.015
# 42            averaging_small_ensemble_size4_seed2  1.601  0.016
# 43   averaging_large_ensemble_size32_seed432384445  1.625  0.027
# 44           averaging_medium_ensemble_size2_seed1  1.670  0.022
# 45            averaging_small_ensemble_size2_seed2  1.817  0.026
# 46          averaging_medium_ensemble_size16_seed2  1.930  0.031
# 47            averaging_large_ensemble_size4_seed2  2.034  0.033
#
#     ensemble_size model_size
# 0              32      small
# 1              32     medium
# 2              16      large
# 3               8      large
# 4               8      large
# 5              32      large
# 6              16     medium
# 7              32     medium
# 8              16     medium
# 9              16      large
# 10              4      large
# 11              8     medium
# 12              8     medium
# 13              8     medium
# 14             16      small
# 15             16      small
# 16             32      small
# 17              2      large
# 18             32     medium
# 19              4     medium
# 20             32      small
# 21              4     medium
# 22              8      small
# 23             16      large
# 24              2      large
# 25             16      small
# 26              8      small
# 27              2      large
# 28             32      large
# 29              1      large
# 30              4      small
# 31              4      large
# 32              8      large
# 33              8      small
# 34              4     medium
# 35              2     medium
# 36              2      small
# 37              2      small
# 38              1     medium
# 39              2     medium
# 40              1      small
# 41              4      small
# 42              4      small
# 43             32      large
# 44              2     medium
# 45              2      small
# 46             16     medium
# 47              4      large

# %%
avg_df = df[df["model_size"] == "large"]
avg_df = avg_df[avg_df.duplicated("ensemble_size", keep=False)].groupby("ensemble_size")["emd"].apply(list).reset_index()
avg_df["avg_emd"] = avg_df["emd"].apply(np.mean)
avg_df["std_emd"] = avg_df["emd"].apply(np.std)
print("Large model")
print(avg_df)
# Out:
# Large model
#    ensemble_size                    emd   avg_emd   std_emd
# 0              2   [1.308, 1.34, 1.372]  1.340000  0.026128
# 1              4   [1.247, 1.42, 2.034]  1.567000  0.337687
# 2              8  [1.182, 1.185, 1.438]  1.268333  0.119979
# 3             16   [1.157, 1.228, 1.33]  1.238333  0.071004
# 4             32   [1.19, 1.374, 1.625]  1.396333  0.178289

# %%
avg_df = df[df["model_size"] == "medium"]
avg_df = avg_df[avg_df.duplicated("ensemble_size", keep=False)].groupby("ensemble_size")["emd"].apply(list).reset_index()
avg_df["avg_emd"] = avg_df["emd"].apply(np.mean)
avg_df["std_emd"] = avg_df["emd"].apply(np.std)
print("Medium model")
print(avg_df)
# Out:
# Medium model
#    ensemble_size                    emd   avg_emd   std_emd
# 0              2   [1.507, 1.579, 1.67]  1.585333  0.066695
# 1              4  [1.313, 1.327, 1.483]  1.374333  0.077051
# 2              8   [1.248, 1.26, 1.269]  1.259000  0.008602
# 3             16   [1.196, 1.218, 1.93]  1.448000  0.340944
# 4             32  [1.153, 1.217, 1.311]  1.227000  0.064890

# %%
avg_df = df[df["model_size"] == "small"]
avg_df = avg_df[avg_df.duplicated("ensemble_size", keep=False)].groupby("ensemble_size")["emd"].apply(list).reset_index()
avg_df["avg_emd"] = avg_df["emd"].apply(np.mean)
avg_df["std_emd"] = avg_df["emd"].apply(np.std)
print("Small model")
print(avg_df)
# Out:
# Small model
#    ensemble_size                    emd   avg_emd   std_emd
# 0              2  [1.515, 1.519, 1.817]  1.617000  0.141431
# 1              4  [1.409, 1.593, 1.601]  1.534333  0.088684
# 2              8  [1.329, 1.353, 1.448]  1.376667  0.051383
# 3             16  [1.271, 1.285, 1.344]  1.300000  0.031633
# 4             32  [1.139, 1.285, 1.322]  1.248667  0.079004

# %%
"""
Bar plot of EMD vs ensemble size
"""
fig, ax = plt.subplots(figsize=(4, 3))

ax.grid()
ax = sns.barplot(
    data=df, 
    x="ensemble_size", 
    y="emd", 
    ax=ax, 
    capsize=0.1, 
    palette="RdYlBu", 
    edgecolor="k", 
    hue="model_size",
)

plt.axhline(y=1.1, linewidth=1, linestyle="--", color="navy", label="Float EMD")

ax.legend()

ax.set_title("Averaging")

fig.tight_layout()
plt.savefig("averaging_emd_v_ensemble_size_barplot.pdf")
plt.savefig("averaging_emd_v_ensemble_size_barplot.png")
# Out:
# /proj/xlabs/users/olivweng/opt/mambaforge/envs/jupyter/lib/python3.9/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /proj/xlabs/users/olivweng/opt/mambaforge/envs/jupyter/lib/python3.9/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /proj/xlabs/users/olivweng/opt/mambaforge/envs/jupyter/lib/python3.9/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /proj/xlabs/users/olivweng/opt/mambaforge/envs/jupyter/lib/python3.9/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):

# %%
"""
Line plot of EMD vs ensemble size
"""
fig, ax = plt.subplots(figsize=(4, 3))

# TODO: Sort df by model size to get consistent colored lines per model size
# across ensemble methods

ax = sns.lineplot(
    data=df, 
    x="ensemble_size", 
    y="emd", 
    ax=ax, 
    hue="model_size", 
    errorbar=(lambda x: (x.min(), x.max())), 
    err_kws={"linewidth": 2}, 
    linewidth=2,
)

# Manually plot with matplotlib
# df_large = df[df["model_size"] == "large"]
# df_small = df[df["model_size"] == "small"]
# df_large = df_large.sort_values("ensemble_size")
# df_small = df_small.sort_values("ensemble_size")
# # df2["avg_emd"] = df2["emd"].apply(np.mean)
# # df2 = df2.sort_values("avg_emd", ignore_index=True)
# print(df_large)

# ax.plot(np.arange(len(df_large["ensemble_size"])), df_large["emd"], label="large")
# ax.plot(np.arange(len(df_large["ensemble_size"])), df_small["emd"], label="small")

plt.axhline(y=1.1, linewidth=1, linestyle="--", color="navy", label="Float model")

# ax.set_xticks(np.arange(len(set(df["ensemble_size"]))))
# ax.set_xticklabels(sorted(set(df["ensemble_size"])))

ax.grid()
ax.legend()
ax.set_title("Averaging")

fig.tight_layout()
plt.savefig("averaging_emd_v_ensemble_size_lineplot.pdf")
plt.savefig("averaging_emd_v_ensemble_size_lineplot.png")
# Out:
# /proj/xlabs/users/olivweng/opt/mambaforge/envs/jupyter/lib/python3.9/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /proj/xlabs/users/olivweng/opt/mambaforge/envs/jupyter/lib/python3.9/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /proj/xlabs/users/olivweng/opt/mambaforge/envs/jupyter/lib/python3.9/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /proj/xlabs/users/olivweng/opt/mambaforge/envs/jupyter/lib/python3.9/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /proj/xlabs/users/olivweng/opt/mambaforge/envs/jupyter/lib/python3.9/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /proj/xlabs/users/olivweng/opt/mambaforge/envs/jupyter/lib/python3.9/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /proj/xlabs/users/olivweng/opt/mambaforge/envs/jupyter/lib/python3.9/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %% [markdown]
# ## Snapshot Ensemble (SSE)

# %%
experiment_dir = "../sse"
df = parse_ensembling_experiment(experiment_dir)
best_single_model_large = {
    "trial": "best_single_model_large",
    "emd": 1.407,
    "loss": 0.012,
    "ensemble_size": 1,
    "model_size": "large",
}
best_single_model_medium = {
    "trial": "best_single_model_medium",
    "emd": 1.558,
    "loss": 0.03,
    "ensemble_size": 1,
    "model_size": "medium",
}
best_single_model_small = {
    "trial": "best_single_model_small",
    "emd": 1.589,
    "loss": 0.022,
    "ensemble_size": 1,
    "model_size": "small",
}
best_single_model_large_df = pd.DataFrame(best_single_model_large, index=[0])
best_single_model_medium_df = pd.DataFrame(best_single_model_medium, index=[0])
best_single_model_small_df = pd.DataFrame(best_single_model_small, index=[0])
df = pd.concat([df, best_single_model_large_df])
df = pd.concat([df, best_single_model_medium_df])
df = pd.concat([df, best_single_model_small_df])
df = df.sort_values("emd", ignore_index=True)
df
# Out:
#                         trial    emd   loss  ensemble_size model_size
# 0     best_single_model_large  1.407  0.012              1      large
# 1    best_single_model_medium  1.558  0.030              1     medium
# 2     best_single_model_small  1.589  0.022              1      small
# 3    sse_small_ensemble_size8  1.670  0.079              8      small
# 4    sse_large_ensemble_size2  1.675  0.020              2      large
# 5   sse_small_ensemble_size32  1.678  0.069             32      small
# 6    sse_small_ensemble_size2  1.686  0.035              2      small
# 7    sse_small_ensemble_size4  1.690  0.047              4      small
# 8    sse_large_ensemble_size4  1.750  0.019              4      large
# 9   sse_small_ensemble_size16  1.755  0.086             16      small
# 10  sse_large_ensemble_size32  1.778  0.021             32      large
# 11  sse_large_ensemble_size16  1.871  0.022             16      large
# 12   sse_large_ensemble_size8  1.968  0.024              8      large

# %%
"""
Bar plot of EMD vs ensemble size
"""
fig, ax = plt.subplots(figsize=(4, 3))

ax.grid()
ax = sns.barplot(data=df, x="ensemble_size", y="emd", ax=ax, capsize=0.2, palette="RdYlBu", edgecolor="k", hue="model_size")

plt.axhline(y=1.1, linewidth=1, linestyle="--", color="navy", label="Float EMD")

ax.legend(loc="lower left")

ax.set_title("Snapshot Ensemble")

fig.tight_layout()
plt.savefig("sse_emd_v_ensemble_size_barplot.pdf")
plt.savefig("sse_emd_v_ensemble_size_barplot.png")
# Out:
# /proj/xlabs/users/olivweng/opt/mambaforge/envs/jupyter/lib/python3.9/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /proj/xlabs/users/olivweng/opt/mambaforge/envs/jupyter/lib/python3.9/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /proj/xlabs/users/olivweng/opt/mambaforge/envs/jupyter/lib/python3.9/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /proj/xlabs/users/olivweng/opt/mambaforge/envs/jupyter/lib/python3.9/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):

# %%
"""
Line plot of EMD vs ensemble size
"""
fig, ax = plt.subplots(figsize=(4, 3))

df["ensemble_size_plot"] = df["ensemble_size"].apply(lambda x: int(np.log2(x)))

# ax = sns.lineplot(data=df, x="ensemble_size_plot", y="emd", ax=ax, hue="model_size")

# Manually plot with matplotlib
df_large = df[df["model_size"] == "large"]
df_small = df[df["model_size"] == "small"]
df_large = df_large.sort_values("ensemble_size")
df_small = df_small.sort_values("ensemble_size")
# df2["avg_emd"] = df2["emd"].apply(np.mean)
# df2 = df2.sort_values("avg_emd", ignore_index=True)
print(df_large)

ax.plot(np.arange(len(df_large["ensemble_size"])), df_large["emd"], label="large")
ax.plot(np.arange(len(df_large["ensemble_size"])), df_small["emd"], label="small")

plt.axhline(y=1.1, linewidth=1, linestyle="--", color="navy", label="Float model")

ax.set_xticks(np.arange(len(set(df["ensemble_size"]))))
ax.set_xticklabels(sorted(set(df["ensemble_size"])))

ax.grid()
ax.legend()
ax.set_ylim([1.05, 2])
ax.set_xlabel("Ensemble size")
ax.set_ylabel("EMD")
ax.set_title("Snapshot Ensemble")

fig.tight_layout()
plt.savefig("sse_emd_v_ensemble_size_lineplot.pdf")
plt.savefig("sse_emd_v_ensemble_size_lineplot.png")
# Out:
#                         trial    emd   loss  ensemble_size model_size  \
# 0     best_single_model_large  1.407  0.012              1      large
# 4    sse_large_ensemble_size2  1.675  0.020              2      large
# 8    sse_large_ensemble_size4  1.750  0.019              4      large
# 12   sse_large_ensemble_size8  1.968  0.024              8      large
# 11  sse_large_ensemble_size16  1.871  0.022             16      large
# 10  sse_large_ensemble_size32  1.778  0.021             32      large
#
#     ensemble_size_plot
# 0                    0
# 4                    1
# 8                    2
# 12                   3
# 11                   4
# 10                   5

# %% [markdown]
# ### SSE + decoder finetuning (5 epochs)

# %%
experiment_dir = "../sse_ft"
df = parse_ensembling_experiment(experiment_dir)
best_single_model_large = {
    "trial": "best_single_model_large",
    "emd": 1.407,
    "loss": 0.012,
    "ensemble_size": 1,
    "model_size": "large",
}
best_single_model_medium = {
    "trial": "best_single_model_medium",
    "emd": 1.558,
    "loss": 0.03,
    "ensemble_size": 1,
    "model_size": "medium",
}
best_single_model_small = {
    "trial": "best_single_model_small",
    "emd": 1.589,
    "loss": 0.022,
    "ensemble_size": 1,
    "model_size": "small",
}
best_single_model_large_df = pd.DataFrame(best_single_model_large, index=[0])
best_single_model_medium_df = pd.DataFrame(best_single_model_medium, index=[0])
best_single_model_small_df = pd.DataFrame(best_single_model_small, index=[0])
df = pd.concat([df, best_single_model_large_df])
df = pd.concat([df, best_single_model_medium_df])
df = pd.concat([df, best_single_model_small_df])
df = df.sort_values("emd", ignore_index=True)
sse_ft_df = df
df
# Out:
#                         trial    emd   loss  ensemble_size model_size
# 0   sse_large_ensemble_size32  1.279  0.008             32      large
# 1   sse_large_ensemble_size16  1.303  0.008             16      large
# 2    sse_large_ensemble_size4  1.346  0.010              4      large
# 3    sse_large_ensemble_size8  1.360  0.010              8      large
# 4    sse_large_ensemble_size2  1.370  0.011              2      large
# 5     best_single_model_large  1.407  0.012              1      large
# 6   sse_small_ensemble_size32  1.480  0.020             32      small
# 7   sse_small_ensemble_size16  1.493  0.020             16      small
# 8    sse_small_ensemble_size8  1.519  0.021              8      small
# 9    best_single_model_medium  1.558  0.030              1     medium
# 10    best_single_model_small  1.589  0.022              1      small
# 11   sse_small_ensemble_size2  1.591  0.022              2      small
# 12   sse_small_ensemble_size4  1.632  0.022              4      small

# %%
"""
Bar plot of EMD vs ensemble size
"""
fig, ax = plt.subplots(figsize=(4, 3))

ax.grid()
ax = sns.barplot(data=df, x="ensemble_size", y="emd", ax=ax, capsize=0.2, palette="RdYlBu", edgecolor="k", hue="model_size")

plt.axhline(y=1.1, linewidth=1, linestyle="--", color="navy", label="Float EMD")

ax.legend(loc="lower left")

ax.set_title("Snapshot Ensemble + finetuning")

fig.tight_layout()
plt.savefig("sse_ft_emd_v_ensemble_size_barplot.pdf")
plt.savefig("sse_ft_emd_v_ensemble_size_barplot.png")
# Out:
# /proj/xlabs/users/olivweng/opt/mambaforge/envs/jupyter/lib/python3.9/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /proj/xlabs/users/olivweng/opt/mambaforge/envs/jupyter/lib/python3.9/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /proj/xlabs/users/olivweng/opt/mambaforge/envs/jupyter/lib/python3.9/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /proj/xlabs/users/olivweng/opt/mambaforge/envs/jupyter/lib/python3.9/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):

# %%
"""
Line plot of EMD vs ensemble size
"""
fig, ax = plt.subplots(figsize=(4, 3))

df["ensemble_size_plot"] = df["ensemble_size"].apply(lambda x: int(np.log2(x)))

ax = sns.lineplot(data=df, x="ensemble_size_plot", y="emd", ax=ax, hue="model_size")


# Manually plot with matplotlib
# df_large = df[df["model_size"] == "large"]
# df_small = df[df["model_size"] == "small"]
# df_large = df_large.sort_values("ensemble_size")
# df_small = df_small.sort_values("ensemble_size")
# # df2["avg_emd"] = df2["emd"].apply(np.mean)
# # df2 = df2.sort_values("avg_emd", ignore_index=True)
# print(df_large)

# ax.plot(np.arange(len(df_large["ensemble_size"])), df_large["emd"], label="large")
# ax.plot(np.arange(len(df_large["ensemble_size"])), df_small["emd"], label="small")

plt.axhline(y=1.1, linewidth=1, linestyle="--", color="navy", label="Float model")

ax.set_xticks(np.arange(len(set(df["ensemble_size"]))))
ax.set_xticklabels(sorted(set(df["ensemble_size"])))

ax.grid()
ax.legend()
ax.set_ylim([1.05, 2])
ax.set_xlabel("Ensemble size")
ax.set_ylabel("EMD")
ax.set_title("Snapshot Ensemble + finetuning")

fig.tight_layout()
plt.savefig("sse_ft_emd_v_ensemble_size_lineplot.pdf")
plt.savefig("sse_ft_emd_v_ensemble_size_lineplot.png")
# Out:
# /proj/xlabs/users/olivweng/opt/mambaforge/envs/jupyter/lib/python3.9/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /proj/xlabs/users/olivweng/opt/mambaforge/envs/jupyter/lib/python3.9/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /proj/xlabs/users/olivweng/opt/mambaforge/envs/jupyter/lib/python3.9/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /proj/xlabs/users/olivweng/opt/mambaforge/envs/jupyter/lib/python3.9/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /proj/xlabs/users/olivweng/opt/mambaforge/envs/jupyter/lib/python3.9/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /proj/xlabs/users/olivweng/opt/mambaforge/envs/jupyter/lib/python3.9/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /proj/xlabs/users/olivweng/opt/mambaforge/envs/jupyter/lib/python3.9/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %% [markdown]
# ### SSE + finetuning (10 epochs)
# Here every member model was trained for minimum 50 epochs (ensemble_size = 16 & 32) or 100 epochs each (ensemble_size = 2, 4, 8) + 10 epochs of decoder finetuning

# %%
experiment_dir = "../sse_more_epochs"
df = parse_ensembling_experiment(experiment_dir)
best_single_model_large = {
    "trial": "best_single_model_large",
    "emd": 1.407,
    "loss": 0.012,
    "ensemble_size": 1,
    "model_size": "large",
}
best_single_model_medium = {
    "trial": "best_single_model_medium",
    "emd": 1.558,
    "loss": 0.03,
    "ensemble_size": 1,
    "model_size": "medium",
}
best_single_model_small = {
    "trial": "best_single_model_small",
    "emd": 1.589,
    "loss": 0.022,
    "ensemble_size": 1,
    "model_size": "small",
}
best_single_model_large_df = pd.DataFrame(best_single_model_large, index=[0])
best_single_model_medium_df = pd.DataFrame(best_single_model_medium, index=[0])
best_single_model_small_df = pd.DataFrame(best_single_model_small, index=[0])
df = pd.concat([df, best_single_model_large_df])
df = pd.concat([df, best_single_model_medium_df])
df = pd.concat([df, best_single_model_small_df])
df = df.sort_values("emd", ignore_index=True)
sse_more_epochs_df = df
df
# Out:
#                                        trial    emd   loss  ensemble_size  \
# 0     sse_large_ensemble_size8_seed432384445  1.296  0.010              8
# 1    sse_large_ensemble_size32_seed432384445  1.298  0.008             32
# 2            sse_large_ensemble_size32_seed1  1.300  0.008             32
# 3    sse_large_ensemble_size16_seed432384445  1.301  0.008             16
# 4             sse_large_ensemble_size8_seed1  1.304  0.008              8
# 5            sse_large_ensemble_size16_seed1  1.310  0.008             16
# 6             sse_large_ensemble_size4_seed1  1.322  0.009              4
# 7     sse_large_ensemble_size4_seed432384445  1.342  0.010              4
# 8   sse_medium_ensemble_size32_seed524926359  1.352  0.024             32
# 9   sse_medium_ensemble_size16_seed524926359  1.354  0.023             16
# 10    sse_large_ensemble_size2_seed432384445  1.355  0.011              2
# 11            sse_large_ensemble_size4_seed2  1.357  0.012              4
# 12          sse_medium_ensemble_size32_seed1  1.362  0.019             32
# 13          sse_medium_ensemble_size32_seed2  1.362  0.023             32
# 14            sse_large_ensemble_size8_seed2  1.362  0.011              8
# 15            sse_large_ensemble_size2_seed1  1.383  0.009              2
# 16          sse_medium_ensemble_size16_seed1  1.391  0.019             16
# 17          sse_medium_ensemble_size16_seed2  1.404  0.023             16
# 18                   best_single_model_large  1.407  0.012              1
# 19            sse_large_ensemble_size2_seed2  1.408  0.012              2
# 20           sse_large_ensemble_size16_seed2  1.410  0.013             16
# 21           sse_large_ensemble_size32_seed2  1.417  0.013             32
# 22   sse_medium_ensemble_size4_seed524926359  1.458  0.025              4
# 23           sse_small_ensemble_size32_seed2  1.472  0.022             32
# 24           sse_small_ensemble_size16_seed2  1.476  0.022             16
# 25    sse_small_ensemble_size8_seed963241121  1.478  0.019              8
# 26            sse_small_ensemble_size8_seed2  1.487  0.022              8
# 27            sse_small_ensemble_size8_seed1  1.506  0.019              8
# 28    sse_small_ensemble_size4_seed963241121  1.510  0.019              4
# 29   sse_small_ensemble_size32_seed963241121  1.517  0.020             32
# 30   sse_medium_ensemble_size2_seed524926359  1.532  0.027              2
# 31           sse_medium_ensemble_size4_seed2  1.533  0.024              4
# 32   sse_small_ensemble_size16_seed963241121  1.541  0.020             16
# 33           sse_medium_ensemble_size4_seed1  1.542  0.020              4
# 34            sse_small_ensemble_size4_seed2  1.547  0.023              4
# 35           sse_small_ensemble_size32_seed1  1.550  0.018             32
# 36           sse_small_ensemble_size16_seed1  1.552  0.018             16
# 37            sse_small_ensemble_size4_seed1  1.555  0.020              4
# 38                  best_single_model_medium  1.558  0.030              1
# 39            sse_small_ensemble_size2_seed2  1.581  0.024              2
# 40                   best_single_model_small  1.589  0.022              1
# 41    sse_small_ensemble_size2_seed963241121  1.599  0.022              2
# 42           sse_medium_ensemble_size2_seed2  1.623  0.026              2
# 43            sse_small_ensemble_size2_seed1  1.652  0.023              2
# 44           sse_medium_ensemble_size2_seed1  1.692  0.024              2
#
#    model_size
# 0       large
# 1       large
# 2       large
# 3       large
# 4       large
# 5       large
# 6       large
# 7       large
# 8      medium
# 9      medium
# 10      large
# 11      large
# 12     medium
# 13     medium
# 14      large
# 15      large
# 16     medium
# 17     medium
# 18      large
# 19      large
# 20      large
# 21      large
# 22     medium
# 23      small
# 24      small
# 25      small
# 26      small
# 27      small
# 28      small
# 29      small
# 30     medium
# 31     medium
# 32      small
# 33     medium
# 34      small
# 35      small
# 36      small
# 37      small
# 38     medium
# 39      small
# 40      small
# 41      small
# 42     medium
# 43      small
# 44     medium

# %%
"""
Bar plot of EMD vs ensemble size
"""
fig, ax = plt.subplots(figsize=(4, 3))

ax.grid()
ax = sns.barplot(data=df, x="ensemble_size", y="emd", ax=ax, capsize=0.2, palette="RdYlBu", edgecolor="k", hue="model_size")

plt.axhline(y=1.1, linewidth=1, linestyle="--", color="navy", label="Float EMD")

ax.legend(loc="lower left")

ax.set_title("Snapshot Ensemble + finetuning (10 epochs)")

fig.tight_layout()
plt.savefig("sse_more_epochs_emd_v_ensemble_size_barplot.pdf")
plt.savefig("sse_more_epochs_emd_v_ensemble_size_barplot.png")
# Out:
# /proj/xlabs/users/olivweng/opt/mambaforge/envs/jupyter/lib/python3.9/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /proj/xlabs/users/olivweng/opt/mambaforge/envs/jupyter/lib/python3.9/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /proj/xlabs/users/olivweng/opt/mambaforge/envs/jupyter/lib/python3.9/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /proj/xlabs/users/olivweng/opt/mambaforge/envs/jupyter/lib/python3.9/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):

# %%
"""
Line plot of EMD vs ensemble size
"""
fig, ax = plt.subplots(figsize=(4, 3))

df["ensemble_size_plot"] = df["ensemble_size"].apply(lambda x: int(np.log2(x)))

ax = sns.lineplot(
    data=df, 
    x="ensemble_size_plot", 
    y="emd", 
    ax=ax, 
    hue="model_size",
    errorbar=(lambda x: (x.min(), x.max())), 
    err_kws={"linewidth": 2}, 
    linewidth=2,
)

plt.axhline(y=1.1, linewidth=1, linestyle="--", color="navy", label="Float model")

ax.set_xticks(np.arange(len(set(df["ensemble_size"]))))
ax.set_xticklabels(sorted(set(df["ensemble_size"])))

ax.grid()
ax.legend()
ax.set_ylim([1.05, 2])
ax.set_xlabel("Ensemble size")
ax.set_ylabel("EMD")
ax.set_title("Snapshot Ensemble + finetuning (10 epochs)")

fig.tight_layout()
plt.savefig("sse_more_epochs_emd_v_ensemble_size_lineplot.pdf")
plt.savefig("sse_more_epochs_emd_v_ensemble_size_lineplot.png")
# Out:
# /proj/xlabs/users/olivweng/opt/mambaforge/envs/jupyter/lib/python3.9/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /proj/xlabs/users/olivweng/opt/mambaforge/envs/jupyter/lib/python3.9/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /proj/xlabs/users/olivweng/opt/mambaforge/envs/jupyter/lib/python3.9/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /proj/xlabs/users/olivweng/opt/mambaforge/envs/jupyter/lib/python3.9/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /proj/xlabs/users/olivweng/opt/mambaforge/envs/jupyter/lib/python3.9/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /proj/xlabs/users/olivweng/opt/mambaforge/envs/jupyter/lib/python3.9/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /proj/xlabs/users/olivweng/opt/mambaforge/envs/jupyter/lib/python3.9/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %% [markdown]
# ## Fast Geometric Ensemble (FGE)

# %%
experiment_dir = "../fge"
df = parse_ensembling_experiment(experiment_dir)
best_single_model_large = {
    "trial": "best_single_model_large",
    "emd": 1.407,
    "loss": 0.012,
    "ensemble_size": 1,
    "model_size": "large",
}
best_single_model_medium = {
    "trial": "best_single_model_medium",
    "emd": 1.558,
    "loss": 0.03,
    "ensemble_size": 1,
    "model_size": "medium",
}
best_single_model_small = {
    "trial": "best_single_model_small",
    "emd": 1.589,
    "loss": 0.022,
    "ensemble_size": 1,
    "model_size": "small",
}
best_single_model_large_df = pd.DataFrame(best_single_model_large, index=[0])
best_single_model_medium_df = pd.DataFrame(best_single_model_medium, index=[0])
best_single_model_small_df = pd.DataFrame(best_single_model_small, index=[0])
df = pd.concat([df, best_single_model_large_df])
df = pd.concat([df, best_single_model_medium_df])
df = pd.concat([df, best_single_model_small_df])
df = df.sort_values("emd", ignore_index=True)
fge_df = df
df
# Out:
#                                        trial    emd   loss  ensemble_size  \
# 0            fge_large_ensemble_size32_seed1  1.304  0.009             32
# 1            fge_large_ensemble_size16_seed1  1.311  0.009             16
# 2    fge_large_ensemble_size32_seed432384445  1.311  0.010             32
# 3    fge_large_ensemble_size16_seed432384445  1.326  0.010             16
# 4             fge_large_ensemble_size8_seed1  1.329  0.009              8
# 5     fge_large_ensemble_size4_seed432384445  1.338  0.010              4
# 6     fge_large_ensemble_size8_seed432384445  1.348  0.010              8
# 7             fge_large_ensemble_size4_seed1  1.355  0.010              4
# 8             fge_large_ensemble_size2_seed1  1.373  0.010              2
# 9     fge_large_ensemble_size2_seed432384445  1.375  0.011              2
# 10           fge_large_ensemble_size32_seed2  1.392  0.013             32
# 11                   best_single_model_large  1.407  0.012              1
# 12           fge_large_ensemble_size16_seed2  1.422  0.013             16
# 13          fge_medium_ensemble_size32_seed2  1.436  0.023             32
# 14  fge_medium_ensemble_size32_seed524926359  1.439  0.022             32
# 15            fge_large_ensemble_size8_seed2  1.442  0.014              8
# 16   fge_small_ensemble_size32_seed963241121  1.464  0.019             32
# 17   fge_small_ensemble_size16_seed963241121  1.468  0.019             16
# 18            fge_large_ensemble_size4_seed2  1.471  0.014              4
# 19          fge_medium_ensemble_size16_seed2  1.472  0.024             16
# 20            fge_large_ensemble_size2_seed2  1.473  0.015              2
# 21  fge_medium_ensemble_size16_seed524926359  1.477  0.023             16
# 22           fge_medium_ensemble_size8_seed2  1.487  0.025              8
# 23    fge_small_ensemble_size8_seed963241121  1.488  0.020              8
# 24    fge_small_ensemble_size4_seed963241121  1.494  0.020              4
# 25   fge_medium_ensemble_size8_seed524926359  1.494  0.024              8
# 26   fge_medium_ensemble_size4_seed524926359  1.512  0.024              4
# 27           fge_medium_ensemble_size4_seed2  1.524  0.025              4
# 28    fge_small_ensemble_size2_seed963241121  1.532  0.021              2
# 29           fge_medium_ensemble_size2_seed2  1.544  0.026              2
# 30   fge_medium_ensemble_size2_seed524926359  1.548  0.025              2
# 31                  best_single_model_medium  1.558  0.030              1
# 32           fge_small_ensemble_size32_seed2  1.562  0.022             32
# 33          fge_medium_ensemble_size32_seed1  1.565  0.023             32
# 34            fge_small_ensemble_size8_seed2  1.570  0.023              8
# 35           fge_small_ensemble_size16_seed2  1.576  0.023             16
# 36           fge_small_ensemble_size32_seed1  1.584  0.022             32
# 37                   best_single_model_small  1.589  0.022              1
# 38            fge_small_ensemble_size4_seed2  1.595  0.023              4
# 39          fge_medium_ensemble_size16_seed1  1.599  0.024             16
# 40            fge_small_ensemble_size8_seed1  1.601  0.023              8
# 41            fge_small_ensemble_size4_seed1  1.619  0.023              4
# 42           fge_medium_ensemble_size8_seed1  1.624  0.024              8
# 43           fge_small_ensemble_size16_seed1  1.629  0.023             16
# 44            fge_small_ensemble_size2_seed2  1.635  0.025              2
# 45            fge_small_ensemble_size2_seed1  1.656  0.024              2
# 46           fge_medium_ensemble_size4_seed1  1.673  0.026              4
# 47           fge_medium_ensemble_size2_seed1  1.696  0.027              2
#
#    model_size
# 0       large
# 1       large
# 2       large
# 3       large
# 4       large
# 5       large
# 6       large
# 7       large
# 8       large
# 9       large
# 10      large
# 11      large
# 12      large
# 13     medium
# 14     medium
# 15      large
# 16      small
# 17      small
# 18      large
# 19     medium
# 20      large
# 21     medium
# 22     medium
# 23      small
# 24      small
# 25     medium
# 26     medium
# 27     medium
# 28      small
# 29     medium
# 30     medium
# 31     medium
# 32      small
# 33     medium
# 34      small
# 35      small
# 36      small
# 37      small
# 38      small
# 39     medium
# 40      small
# 41      small
# 42     medium
# 43      small
# 44      small
# 45      small
# 46     medium
# 47     medium

# %%
"""
Line plot of EMD vs ensemble size
"""
fig, ax = plt.subplots(figsize=(4, 3))

df["ensemble_size_plot"] = df["ensemble_size"].apply(lambda x: int(np.log2(x)))

ax = sns.lineplot(
    data=df, 
    x="ensemble_size_plot", 
    y="emd", 
    ax=ax, 
    hue="model_size",
    errorbar=(lambda x: (x.min(), x.max())), 
    err_kws={"linewidth": 2}, 
    linewidth=2,
)

plt.axhline(y=1.1, linewidth=1, linestyle="--", color="navy", label="Float model")

ax.set_xticks(np.arange(len(set(df["ensemble_size"]))))
ax.set_xticklabels(sorted(set(df["ensemble_size"])))

ax.grid()
ax.legend()
ax.set_ylim([1.05, 2])
ax.set_xlabel("Ensemble size")
ax.set_ylabel("EMD")
ax.set_title("Fast Geometric Ensemble + finetuning (10 epochs)")

fig.tight_layout()
plt.savefig("fge_emd_v_ensemble_size_lineplot.pdf")
plt.savefig("fge_emd_v_ensemble_size_lineplot.png")
# Out:
# /proj/xlabs/users/olivweng/opt/mambaforge/envs/jupyter/lib/python3.9/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /proj/xlabs/users/olivweng/opt/mambaforge/envs/jupyter/lib/python3.9/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /proj/xlabs/users/olivweng/opt/mambaforge/envs/jupyter/lib/python3.9/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /proj/xlabs/users/olivweng/opt/mambaforge/envs/jupyter/lib/python3.9/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /proj/xlabs/users/olivweng/opt/mambaforge/envs/jupyter/lib/python3.9/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /proj/xlabs/users/olivweng/opt/mambaforge/envs/jupyter/lib/python3.9/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /proj/xlabs/users/olivweng/opt/mambaforge/envs/jupyter/lib/python3.9/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %% [markdown]
# ## Ensembling Comparison

# %%
averaging_df["ensemble_method"] = averaging_df["model_size"].apply(lambda x: "Averaging")
sse_ft_df["ensemble_method"] = sse_ft_df["model_size"].apply(lambda x: "SSE")
sse_more_epochs_df["ensemble_method"] = sse_more_epochs_df["model_size"].apply(lambda x: "SSE (more epochs)")
fge_df["ensemble_method"] = fge_df["model_size"].apply(lambda x: "FGE")
all_df = pd.concat([averaging_df, sse_ft_df])
all_df = pd.concat([all_df, sse_more_epochs_df])
all_df = pd.concat([all_df, fge_df])
all_df
# Out:
#                                            trial    emd   loss  ensemble_size  \
# 0          averaging_small_ensemble_size32_seed1  1.139  0.007             32
# 1         averaging_medium_ensemble_size32_seed1  1.153  0.007             32
# 2          averaging_large_ensemble_size16_seed1  1.157  0.007             16
# 3           averaging_large_ensemble_size8_seed2  1.182  0.007              8
# 4   averaging_large_ensemble_size8_seed432384445  1.185  0.007              8
# ..                                           ...    ...    ...            ...
# 43               fge_small_ensemble_size16_seed1  1.629  0.023             16
# 44                fge_small_ensemble_size2_seed2  1.635  0.025              2
# 45                fge_small_ensemble_size2_seed1  1.656  0.024              2
# 46               fge_medium_ensemble_size4_seed1  1.673  0.026              4
# 47               fge_medium_ensemble_size2_seed1  1.696  0.027              2
#
#    model_size ensemble_method  ensemble_size_plot
# 0       small       Averaging                 NaN
# 1      medium       Averaging                 NaN
# 2       large       Averaging                 NaN
# 3       large       Averaging                 NaN
# 4       large       Averaging                 NaN
# ..        ...             ...                 ...
# 43      small             FGE                 4.0
# 44      small             FGE                 1.0
# 45      small             FGE                 1.0
# 46     medium             FGE                 2.0
# 47     medium             FGE                 1.0
#
# [154 rows x 7 columns]

# %%
"""
Boxplot comparing all methods (Large model)
"""
fig, ax = plt.subplots(figsize=(6, 4))

large_df = all_df[all_df["model_size"] == "large"]

ax = sns.boxplot(data=large_df, x="ensemble_size", y="emd", hue="ensemble_method", palette="Spectral")

ax.grid()
ax.legend()
ax.set_ylim([1.1, 2.1])
ax.set_xlabel("Ensemble size")
ax.set_ylabel("EMD")
ax.set_title("Large Model")

fig.tight_layout()
# Out:
# /proj/xlabs/users/olivweng/opt/mambaforge/envs/jupyter/lib/python3.9/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /proj/xlabs/users/olivweng/opt/mambaforge/envs/jupyter/lib/python3.9/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /proj/xlabs/users/olivweng/opt/mambaforge/envs/jupyter/lib/python3.9/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /proj/xlabs/users/olivweng/opt/mambaforge/envs/jupyter/lib/python3.9/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):

# %%
ax = sns.lineplot(
    data=large_df, 
    x="ensemble_size", 
    y="emd", 
    hue="ensemble_method", 
    errorbar=(lambda x: (x.min(), x.max())), 
    err_kws={"linewidth": 2}, 
    linewidth=2,
)

ax.grid()
ax.legend()
ax.set_ylim([1.1, 2.1])
ax.set_xlabel("Ensemble size")
ax.set_ylabel("EMD")
ax.set_title("Large Model")

fig.tight_layout()
# Out:
# /proj/xlabs/users/olivweng/opt/mambaforge/envs/jupyter/lib/python3.9/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /proj/xlabs/users/olivweng/opt/mambaforge/envs/jupyter/lib/python3.9/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /proj/xlabs/users/olivweng/opt/mambaforge/envs/jupyter/lib/python3.9/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /proj/xlabs/users/olivweng/opt/mambaforge/envs/jupyter/lib/python3.9/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /proj/xlabs/users/olivweng/opt/mambaforge/envs/jupyter/lib/python3.9/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /proj/xlabs/users/olivweng/opt/mambaforge/envs/jupyter/lib/python3.9/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /proj/xlabs/users/olivweng/opt/mambaforge/envs/jupyter/lib/python3.9/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /tmp/ipykernel_643336/3868062630.py:18: UserWarning: The figure layout has changed to tight
#   fig.tight_layout()

# %%
"""
Boxplot comparing all methods (Small model)
"""
fig, ax = plt.subplots(figsize=(6, 4))

small_df = all_df[all_df["model_size"] == "small"]

ax = sns.boxplot(data=small_df, x="ensemble_size", y="emd", hue="ensemble_method", palette="Spectral")

ax.grid()
ax.legend()
ax.set_ylim([1.1, 2.1])
ax.set_xlabel("Ensemble size")
ax.set_ylabel("EMD")
ax.set_title("Small Model")

fig.tight_layout()
# Out:
# /proj/xlabs/users/olivweng/opt/mambaforge/envs/jupyter/lib/python3.9/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /proj/xlabs/users/olivweng/opt/mambaforge/envs/jupyter/lib/python3.9/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /proj/xlabs/users/olivweng/opt/mambaforge/envs/jupyter/lib/python3.9/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /proj/xlabs/users/olivweng/opt/mambaforge/envs/jupyter/lib/python3.9/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):

# %%
ax = sns.lineplot(
    data=small_df, 
    x="ensemble_size", 
    y="emd", 
    hue="ensemble_method", 
    errorbar=(lambda x: (x.min(), x.max())), 
    err_kws={"linewidth": 2}, 
    linewidth=2,
)

ax.grid()
ax.legend()
ax.set_ylim([1.1, 2.1])
ax.set_xlabel("Ensemble size")
ax.set_ylabel("EMD")
ax.set_title("Small Model")

fig.tight_layout()
# Out:
# /proj/xlabs/users/olivweng/opt/mambaforge/envs/jupyter/lib/python3.9/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /proj/xlabs/users/olivweng/opt/mambaforge/envs/jupyter/lib/python3.9/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /proj/xlabs/users/olivweng/opt/mambaforge/envs/jupyter/lib/python3.9/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /proj/xlabs/users/olivweng/opt/mambaforge/envs/jupyter/lib/python3.9/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /proj/xlabs/users/olivweng/opt/mambaforge/envs/jupyter/lib/python3.9/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /proj/xlabs/users/olivweng/opt/mambaforge/envs/jupyter/lib/python3.9/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /proj/xlabs/users/olivweng/opt/mambaforge/envs/jupyter/lib/python3.9/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /tmp/ipykernel_643336/239150931.py:18: UserWarning: The figure layout has changed to tight
#   fig.tight_layout()

# %%
"""
Boxplot comparing all methods (Medium model)
"""
fig, ax = plt.subplots(figsize=(6, 4))

med_df = all_df[all_df["model_size"] == "medium"]

ax = sns.boxplot(data=med_df, x="ensemble_size", y="emd", hue="ensemble_method", palette="Spectral")

ax.grid()
ax.legend()
ax.set_ylim([1.1, 2.1])
ax.set_xlabel("Ensemble size")
ax.set_ylabel("EMD")
ax.set_title("Medium Model")

fig.tight_layout()
# Out:
# /proj/xlabs/users/olivweng/opt/mambaforge/envs/jupyter/lib/python3.9/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /proj/xlabs/users/olivweng/opt/mambaforge/envs/jupyter/lib/python3.9/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /proj/xlabs/users/olivweng/opt/mambaforge/envs/jupyter/lib/python3.9/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /proj/xlabs/users/olivweng/opt/mambaforge/envs/jupyter/lib/python3.9/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):

# %%
ax = sns.lineplot(data=med_df, x="ensemble_size", y="emd", hue="ensemble_method", linewidth=2)

ax.grid()
ax.legend()
ax.set_ylim([1.1, 2.1])
ax.set_xlabel("Ensemble size")
ax.set_ylabel("EMD")
ax.set_title("Medium Model")

fig.tight_layout()
# Out:
# /proj/xlabs/users/olivweng/opt/mambaforge/envs/jupyter/lib/python3.9/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /proj/xlabs/users/olivweng/opt/mambaforge/envs/jupyter/lib/python3.9/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /proj/xlabs/users/olivweng/opt/mambaforge/envs/jupyter/lib/python3.9/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /proj/xlabs/users/olivweng/opt/mambaforge/envs/jupyter/lib/python3.9/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /proj/xlabs/users/olivweng/opt/mambaforge/envs/jupyter/lib/python3.9/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /proj/xlabs/users/olivweng/opt/mambaforge/envs/jupyter/lib/python3.9/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /proj/xlabs/users/olivweng/opt/mambaforge/envs/jupyter/lib/python3.9/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /tmp/ipykernel_643336/3269983742.py:10: UserWarning: The figure layout has changed to tight
#   fig.tight_layout()
